# %% [markdown]
# # Website scraping
#
# ---
#
# Group name: Gruppe G
#
# ---

# %% [markdown]
# # Setup für die Aufgabe:
# ## Hierfür wird die Programmbibliothek BeautifulSoup sowie pandas benötigt.

# %%
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Scrapen der Website:
# ## Hierfür wird ein GET-request genutzt und die entsprechende Seite in "url" gespeichert.
# ## Gruppe G hat sich für einen Artikel der Website "fivethirtyeight" entschieden.

# %%
url = 'https://fivethirtyeight.com/features/election-explanations-are-hard/'

# %%
html = requests.get(url)

# %% [markdown]
# ## Zur Überprüfung, ob die Durchführung funktioniert hat wird eine Statusabfrage genutzt:

# %%
html.status_code
# Out:
# 200

# %% [markdown]
# ## Die Rückgabe "200" bedeudeutet, dass es funktioniert hat.

# %% [markdown]
# ## Da nur der Text der Website relevant ist, soll auch nur dieser für die Analyse verwendet werde.
# ## Aus diesem Grund wird durch BeautifulSoup mithilfe des "html.parser" nur der HTML-Text extrahiert.

# %%
soup = BeautifulSoup(html.text, 'html.parser')

# %% [markdown]
# ## Durch "soup" kann das Dokument als verschachtelte Datenstruktur geprinted werden.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="//dcf.espn.com" rel="dns-prefetch"/>
#   <script src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js">
#   </script>
#   <title>
#    So You Think You Can Explain The Election | FiveThirtyEight
#   </title>
#   <meta content="max-image-preview:large" name="robots">
#    <link as="font" crossorigin="anonymous" href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/dist/fonts/AtlasGrotesk-Bold-Web.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/dist/fonts/AtlasGrotesk-Regular-Web.woff2" rel="preload" type="font/woff2"/>
# ...

# %% [markdown]
# ## Um den gesamten Text anzusehen wird der Befehl "print(soup.get_text())" genutzt.
# ## Der Text überschreitet allerdigs das Zeichenlimit und wird deshalb nicht komplett angezeigt.

# %%
print(soup.get_text())
# Out:
# So You Think You Can Explain The Election | FiveThirtyEight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
#
#
#
#
#
#
#
# FiveThirtyEight
#
#
#
#
#
# Search
#
#
#
# Search
#
#
#
#
# ABC News
#
# Menu
#
#
#
#
# 											So You Think You Can Explain The Election
# Share on Facebook
# Share on Twitter
#
#
#
#
#
#
# 						Politics
#
#
#
# 						Sports
#
#
#
# 						Science
#
#
#
# 						Podcasts
#
#
#
# 						Video
#
#
#
# 						ABC News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2022 Election
# So You Think You Can Explain The Election
#
#
#
# By Maggie Koerth
#
#
# 									Nov. 18, 2022, at 10:19 AM
#
#
#
#
#
#
#
#
# PHOTO ILLUSTRATION BY EMILY SCHERER / GETTY IMAGES
#
#
# ...

# %%
article_all = soup.find_all('div', {'class' : 'entry-content single-post-content'})
article_all
# Out:
# [<div class="entry-content single-post-content">
#  <div class="wp-block-abc-blocks-article-header abc-blocks-article-header--short-form abc-blocks-article-header--default abc-blocks-article-header--without-dek">
#  <div class="abc-blocks-article-header__container">
#  <header class="post-info single-post-header"><div class="single-header">
#  <p class="single-metadata single-topic"><a class="term" href="https://fivethirtyeight.com/tag/2022-election/" name="">2022 Election</a></p>
#  <h1 class="article-title article-title-single entry-title">So You Think You Can Explain The Election</h1>
#  </div>
#  <div class="single-header-metadata-and-share-wrap">
#  <div class="single-header-metadata-wrap">
#  <p class="single-metadata single-byline vcard">By <a class="author url fn" href="https://fivethirtyeight.com/contributors/maggie-koerth/" rel="author" title="">Maggie Koerth</a></p>
#  <p class="topic single-topic">
#  <time class="datetime">
# ...

# %% [markdown]
# ## Um die Daten in einer Panda Dataframe zu speicher.

# %%
df_all = pd.DataFrame({"webscraping.csv" : article_all})

# %% [markdown]
# ## "webscraping.csv" soll im Unterordner "data/raw" gespeichert werden.
